# %%
import collections

# %%
all_elements = ['pronoun', 'This', 'I', 'auxiliary','is', 'determiner','a', 'the', 'adverb','very', 'Currently', 'adjective','simple', 'noun','DtM', 'type', 'STLs', 'model', 'material', 'remix', 'callout', 'adposition','with', 'of', 'for', 'punctuation','-', '.', ',', 'numeral','v3.0_0', 'verb','included', 'proper noun','PETG', 'PLA', 'coordinating conjunction','and','particle','to', 'not', 'To', 'verb','entering', 'prevent', 'using', 'undergoing', 'hold', 'assemble', 'print', 'shields', 'incorperating', 'use', 'require', 'based', 'takes', 'uses', 'cut', 'made', 'located', 'covered', 'opposed', 'numeral','3', '16', '30', 'mm', 'two', 'adposition','of', 'in', 'for', 'above', 'with', 'from', 'to', 'on', 'at', 'pronoun','both', 'them', 'these', 'adverb','more', 'here', 'once', 'currently', 'determiner','some', 'This', 'a', 'the', 'any', 'noun','rettenion', 'shield', 'googles', 'custom', 'remix', 'Improvements', 'Improvments', 'doctors', 'Transparency', 'face', 'sheet', 'tolerances', 'transparency', 'film', 'Rc3', 'hole', 'hospitals', 'testing', 'droplets', 'pegs', 'puncher', 'plastic', 'sets', 'elements', 'frame', 'saftey', 'section', 'space', 'feedback', 'head', 'system', 'band', 'punches', 'design', 'stl', 'punctuation','(', ',', ',', '.', ')', 'space','', '', 'coordinating conjunction','or', 'and', 'adjective','additonal', 'larger', 'hybrid', 'best', 'other', 'front', 'reliable', 'material', 'less', 'Easier', 'clear', 'standard', 'More', 'elestic', 'Top', 'auxiliary','be', 'Does', 'Can', 'is', 'proper noun','Prusa', 'RC3', 'Faster', 'becuase', 'subordinating conjunction','as', 'link','https,//3dverkstan.se/protective-visor/', 'https,//drive.google.com/file/d/1gZOMuNRu5D1Orhv3VAqHKbbJAdb9KCdN/view?usp=sharing', 'https,//www.prusaprinters.org/prints/25857-prusa-protective-face-shield-rc2','pronoun','This', 'that', 'auxiliary','is', 'determiner','This', 'a', 'the', 'No', 'this', 'adjective','other', 'single', 'partial', 'transparent', '3D', 'necessary', 'washable', 'noun','speeds', 'face', 'reuse', 'shield', 'materials', 'assembly', 'visor', 'piece', 'headband', 'adverb','only', 'verb','encourages', 'requires', 'productoin', 'coordinating conjunction','or', 'and', 'proper noun','Printed', 'PET', 'punctuation','.', 'adposition','of', 'space','','determiner','This', 'a', 'The', 'the', 'No', 'noun','D', 'layer', 'shield', 'clearance', 'shortage', 'doctors', 'hundreds', 'ABS', 'lot', 'staff', 'face', 'gear', 'modification', 'tolerances', 'authority', 'tools', 'production', 'sizes', 'world', 'regulations', 'sheets', 'heights', 'mm', 'guidelines', 'review', 'eyes', 'minutes', 'protection', 'plastic', 'features', 'materials', 'following', 'model', 'nozzle', 'supplies', 'nurses', 'visor', 'setting', 'frame', 'section', 'printers', 'region', 'shields', 'verb','approved', 'instructed', 'is', 'using', 'refers', 'holding', 'authorized', 'assemble', 'recommended', 'print', 'make', 'tuned', 'Using', 'used', 'requiring', 'works', 'tested', 'based', 'are', 'follow', 'fabricated', 'applies', 'regarding', 'designed', 'adposition','over', 'of', 'in', 'for', 'during', 'During', 'outside', 'above', 'within', 'up', 'with', 'by', 'to', 'on', 'than', 'as', 'punctuation','(', ',', '"', ',', '.', ')', '-', '“', 'numeral','20', '1', '3DVerkstan', '5', '3DPX-013306', 'mm', '0.5', 'space',' ', '', '', 'proper noun','Masks', 'Staff', 'New', 'PETG', 'Presbyterian', 'Medical', 'Hospital', 'Design', 'Coronavirus', 'Industry', 'Columbia', 'University', 'COVID-19', 'Drip', 'Part', 'Administration', 'Center', 'Public', 'Printable', 'CPE', 'Enforcement', 'Guidance', 'Policy', 'FDA', 'Emergency', 'PLA', 'Food', 'Disease', 'Health', 'York', 'Respirators', 'Drug', 'Face', 'auxiliary','is', 'are', 'been', 'has', 'adjective','sized', 'possible', 'Quick', 'little', 'common', 'pandemic', 'normal', 'tight', 'less', 'easy', 'standard', 'clinical', 'plastic', 'different', 'printable', 'protective', 'undergone', 'available', 'sure', 'medical', 'most', 'adverb','readily', 'all', 'pathway', 'so', 'well', 'currently', 'only', 'equally', 'as', 'coordinating conjunction','but', 'and', 'subordinating conjunction','as', 'when', 'pronoun','your', 'there', 'who', 'them', 'All', 'There', 'that', 'particle','to', 'other','etc', 'interjection','please', 'symbol','pronoun','I', 'This', 'its', 'there', 'Our', 'auxiliary','has', 'can', 'did', 'have', 'is', 'was', 'would', 'determiner','NO', 'This', 'a', 'The', 'the', 'this', 'noun','DtM', 'v3.1', 'blobs', 'points', 'artifacts', 'remix', 'software', 'fact', 'group', 'retractions', 'thickness', 'face', 'file', 'width', 'gap', 'pegs', 'perimeters', 'model', 'LOGO', 'splatter', 'problem', 'number', 'guard', 'parent', 'fill', 'adposition','without', 'of', 'between', 'from', 'at', 'punctuation', 'proper noun','Model', 'Shield', '3DPX-013359', 'ID', 'PPE', '3DPPGH', 'Face', 'adjective','printable', 'consistent', 'certain', 'front', 'strange', '3D', 'excess', 'unaltered', 'easier', 'verb','remains', 'noticed', 'stemming', 'print', 'were', 'have', 'switch', 'printed', 'fixed', 'sanitize', 'left', 'means', 'slicing', 'headband', 'adverb','therefore', 'now', 'largely', 'very', 'alone', 'other','#', 'coordinating conjunction','and', 'subordinating conjunction','because', 'that', 'particle','to', 'not', 'numeral','2.4', 'mm', 'space',''
,'adposition','without', 'in', 'of', 'for', 'above', 'with', 'between', 'from', 'Due', 'by', 'to', 'on', 'as', 'particle','to', "'s", 'verb','partnered', 'prevent', 'printed', 'using', 'recommended', 'closed', 'validated', 'obstructing', 'backed', 'features', 'aims', 'following', 'aerosol', 'caused', 'develop', 'preferred', 'based', 'provide', 'modified', 're', 'cut', 'accepted', 'supply', 'worn', 'noun','bracket', 'health', 'stethoscope', 'shield', 'workers', 'PETG', 'material', 'equipment', 'remix', 'ear', 'Thickness', 'shortages', 'hearing', 'pandemic', 'care', 'cell', 'user', 'face', 'Polyurethane', 'front', 'COVID-19', 'Shield.dxf', 'testing', 'inch', 'mm', 'use', 'disruption', 'professionals', 'ventilation', 'adhesive', 'headband', 'alternative', 'summary', 'strap', 'fogging', 'hook', 'protection', 'splatter', 'materials', '3D', 'clinician', 'decontamination', 'tape', 'ears', 'access', 'day', 'visor', 'PanFab-FaceShield-Headband-Bottom_reinforcement.stl', 'preprint', 'input', 'exposure', 'die', 'foam', 'loop', 'article', 'chain', 'limits', 'neoprene', 'laser', 'comfort', 'healthcare', 'cab', 'design', 'length', 'punctuation','(', ',', '"', '~20', ',', '.', ')', '-', 'determiner','an', 'This', 'a', 'all', 'the', 'this', 'auxiliary',"'s", 'has', 'are', 'can', 'is', 'be', 'adjective','usable', 'severe', 'personal', 'comfortable', 'long', 'appropriate', 'wide', 'top', 'rotary', 'alternative', 'clinical', 'thick', 'protective', '~6', 'Preferred', 'available', 'single', 'other', 'transparent', '-', 'proper noun','PMMA', 'PanFab-FaceShield-Headband.stl', 'Prusa', 'Hospital', 'Foam.dxf', 'FaceShield', 'PET', 'Thickness', 'Nylon', 'EVA', 'Transparent', 'Brigham', 'BWH', 'Mylar', 'Women', 'Foam', 'Provide', 'PPE', 'Part', 'mm', 'HeadBuffer', 'Bottom', 'PEI', '3D', 'Name', 'Hook', 'Emergency', 'PLA', 'Department', 'Materials', 'BoPET', 'Bill', 'PanFab', 'pronoun','We', 'its', 'The', 'it', 'that', 'coordinating conjunction','or', 'either', 'nor', 'and', 'space',' ', '', '', 'other','The', 'adverb','enough', 'directly', 'numeral','0.2', 'mm', '0.75', '330', '0.7', '0.5', '190', 'symbol','-', 'subordinating conjunction','If'
,'pronoun','This', 'These', 'What', 'it', 'You', 'auxiliary','are', 'can', 'is', 'should', 'be', 'determiner','this', 'a', 'the', 'no', 'noun','license', 'designers', 'face', 'layer', 'modifications', 'shield', 'distance', 'information', 'web', 'model', 'site', 'remix', 'nozzle', 'files', 'mm', 'height', 'headband', 'adposition','of', 'in', 'with', 'from', 'on', 'adjective','popular', 'More', 'stackable', 'original', 'coordinating conjunction','and', 'adverb','already', 'here', 'also', 'proper noun','PLA', 'NIH', 'verb','differentiates', 'make', 'approved', 'printed', 'found', 'find', 'numeral','0.28', '0.4', '3DVerkstan', 'punctuation',',', '.', ',', 'particle','to', 'space','', 'link','https,//github.com/Cederb/Faceshield.nu/', 'https,//3dverkstan.se/protective-visor/','noun','face', 'rubberbands', 'Laser', 'foam', 'shield', 'materials', 'headband', 'punctuation','(', ',', '.', ')', '-', 'verb','require', 'cut', 'coordinating conjunction','and', 'pronoun','that', 'auxiliary','does', 'particle','not', 'determiner','any', 'adjective','consumable', 'other','i.e.', 'etc', 'space','proper noun','Tprestero', 'particle',"'s", 'to', 'adjective','Inner', 'excellent', 'adhesive', 'elastic', 'noun','glide', 'face', 'foam', 'shield', 'clips', 'pad', 'comfort', 'band', 'inch', 'headband', 'adposition','with', 'for', 'determiner','a', 'numeral','1', 'punctuation','-', '.', 'pronoun','you', 'which', 'auxiliary','can', 'is', 'adverb','also', 'then', 'verb','adjust', 'heightened', 'accomodate', 'coordinating conjunction','and', 'space',''
,'interjection','Please', 'verb','find', 'determiner','all', 'noun','information', 'adposition','on', 'proper noun','www.faceshield.us', 'space',''
,'determiner','This', 'a', 'The', 'the', 'A', 'this', 'All', 'noun','times', 'health', 'designs', 'minute', 'stethoscope', 'strip', 'shield', 'D', 'filament', '#', 'sterilization', 'forehead', 'clearance', 'UV', 'safety', 'pandemic', 'improvements', 'Transparency', 'bands', 'face', 'tesselation', 'production', 'print', 'ring', 'Silicone', 'time', 'testing', 'rubber', 'standard', 'use', 'droplets', 'groups', 'variety', 'autoclave', 'PC', 'review', 'materials', 'goggles', '3D', 'O', 'visor', 'hair', 'setting', 'cycle', 'Features', 'frame', 'bleach', 'section', 'industry', 'coverage', 'Materials', 'cut', 'pathway', 'laser', 'comfort', 'excess', 'tie', 'respirator', 'design', 'shields', 'coordinating conjunction','but', 'or', 'and', 'verb','prevent', 'instructed', 'printed', 'provided', 'authorized', 'adapt', 'recommended', 'Nesting', 'provides', 'produced', 'terephthalate', 'suggest', 'enables', 'shipped', 'used', 'tested', 'based', 'cut', 'fabricated', 'optimized', 'covered', 'pronoun','that', 'auxiliary','are', 'has', 'can', 'is', 'been', 'be', 'adposition','due', 'out', 'of', 'in', 'for', 'during', 'During', 'above', 'outside', 'from', 'near', 'on', 'to', 'off', 'at', 'punctuation','(', ',', '"', ',', '.', ')', '-', '4869A2', '“', 'adverb','heavily', 'Originally', 'e.g.', 'Currently', 'proper noun','QTY', 'Masks', 'Staff', 'New', 'Polypropylene', 'Respirators', 'Drug', 'PET', 'G', 'Coronavirus', 'Scale', 'Boston', 'Ochsner', 'Asylum', 'Industry', 'Orleans', 'Workspace', 'COVID-19', 'Space', 'Part', 'Artisan', 'Administration', 'Public', 'Mcmaster', '3D', 'FDA', 'Enforcement', 'Policy', 'Guidance', 'Somerville', 'Covid-19', 'Emergency', 'Disease', 'Food', 'Health', 'Polycarbonate', 'Bill', 'MA', 'Access', 'Face', 'adjective','Polyethylene', 'normal', 'protective', 'undergone', 'local', 'optional', 'reusable', 'mass', 'elastic', 'insufficient', 'near', 'Top', 'significant', 'clinical', 'safe', 'original', 'particle',"'s", 'to', 'subordinating conjunction','if', 'that', 'as', 'when', 'numeral','1', '1/8', '5', '90W', '1350', '0.04', 'space',' ', '', '', 'other','..', 'etc'
,'verb','uses', 'Designed', 'adposition','with', 'for', 'adjective','fast', 'minimal', 'multiple', 'noun','strap', 'support', 'pattern', 'material', 'hole', 'printing', 'configurations', 'coordinating conjunction','and', 'punctuation','"', ';', 'proper noun','Budmen', 'space',''
,'noun','holes', 'Design', 'film', 'hole', 'deployment', 'time', 'sheets', 'minimalist', 'bandcompletes', 'number', 'frame', 'SPEED', 'band', 'strength', 'loops', 'rigidity', 'Face', 'elbow', 'shield', 'resilience', 'styles', 'parts', 'office', 'user', 'pins', 'production', 'instructions', 'punch', 'template', 'protection', 'side', 'tearing', 'hand', 'system', 'wrap', 'supply', 'version', 'structure', 'saran', 'material', 'forehead', 'face', 'transparency', 'front', 'width', 'DESIGNS', 'headstrap', 'support', 'choice', '3D', 'healthcare', 'fastener', 'pictures', 'gram', 'workers', 'store', 'need', 'size', 'grams', 'product', 'durability', 'PDF', 'fasteners', 'puncher', 'strap', 'impact', 'splatter', 'Requirements', 'ways', 'works', 'paper', 'head', 'weight', 'Overview', 'complexity', 'design', 'length', 'punctuation','”', '"', ',', '(', ',', '!', '.', ')', '–', '“', 'determiner','some', 'This', 'a', 'An', 'all', 'The', 'the', 'A', 'any', 'verb','push', 'provide', 'choose', 'intended', 'Cut', 'printed', '¼', 'provided', 'printing', 'using', 'minimize', 'tear', 'frontline', 'face', 'woven', 'yields', 'get', 'start', 'secure', 'See', 'Protect', 'Starting', 'punch', 'use', 'Continue', 'depending', 'support', 'PROVIDED', 'maximize', 'Use', 'Achieved', 'continue', 'weights', 'secured', 'procured', 'maintaining', 'cutting', 'added', 'MANUFACTURING', 'improvised', 'Select', 'Ensure', 'has', 'utilized', 'wear', 'align', 'cut', 'accept', 'optimized', 'allows', 'unsecure', 'help', 'attached', 'designed', 'particle','to', 'Not', "'s", 'numeral','1/4', '1/2', '11', '1', '3', '7', '4', 'one', '2', '9', '8', '14', '28', '32', 'two', 'symbol','=', ',', '.', '-', 'x', 'auxiliary','can', 'is', 'have', 'should', 'ARE', 'Can', 'be', 'adposition','due', 'without', 'of', 'in', 'for', 'after', 'into', 'FOR', 'visibilty', 'Of', 'off', 'with', 'onto', 'from', 'to', 'on', 'via', 'at', 'adjective','short', 'Easy', 'shield', 'more', 'complete', 'right', 'pandemic', 'woven', 'fluid', 'greater', 'Total', 'same', 'clear', 'standard', 'multiple', 'Robust', 'elastic', 'left', 'additional', 'single', 'rapid', 'full', 'coordinating conjunction','OR', 'or', 'either', 'and', 'subordinating conjunction','till', 'if', 'while', 'when', 'adverb','upward', 'only', 'mostly', 'proper noun','Printed', 'COMFORT', 'Allow', '¾', 'SIZE', 'Design', 'ACTUAL', 'test', 'ADDED', 'fit', 'Forehead', 'Choice', 'PDF', 'Assembly', 'Instructions', 'Tolerable', 'Material', 'Minimize', 'Comfortable', 'Covid-19', 'Frame', 'Bill', 'Hole', 'Curve', 'Print', 'Head', 'space',' ', '', '', 'pronoun','that', 'Your', 'your', 'it', 'you'
,'determiner','some', 'This', 'a', 'The', 'the', 'noun','volume', 'designs', '%', 'points', 'need', 'printing', 'infill', 'production', 'print', 'file', 'info', 'page', 'community', 'increase', 'time', 'device', 'use', 'pressure', 'grabcad', 'assembly', 'files', 'settings', 'cross', 'crowd', 'section', 'foam', 'cost', 'padding', 'comfort', '-', 'complexity', 'design', 'auxiliary','be', 'can', 'was', 'is', 'verb','reduced', 'reduce', 'helps', 'eliminating', 'hope', 'increase', 'printed', 'optimized', 'found', 'using', 'produce', 'sourced', 'designed', 'adposition','to', 'on', 'for', 'coordinating conjunction','&', 'or', 'and', 'particle','to', 'punctuation', ',', ',', '!', '.', 'space',' ', '', 'pronoun','I', 'This', 'my', 'which', 'it', 'adjective','elliptical', 'durable', 'additional', 'other', 'free', 'comfortable', 'coarse', 'More', 'unsanitary', 'adverb','down', 'here', 'thereby', 'numeral','30', 'link','https,//grabcad.com/library/arista-face-shield-1' ,'pronoun','This', 'there', 'auxiliary','be', 'can', 'is', 'determiner','each', 'a', 'The', 'A', 'the', 'noun','shape', 'version', 'mil', 'shield', 'material', 'remix', 'face', 'projector', 'reinforcement', 'print', 'hole', 'hinge', 'sheets', 'covers', 'punch', 'result', 'side', 'profile', 'sides', 'mold', 'visor', 'place', 'injection', 'bottom', 'tabs', 'report', 'system', 'rigidity', 'adposition','around', 'of', 'in', 'for', 'with', 'on', 'to', 'As', 'than', 'as', 'proper noun','DtM', 'Prusa', 'RC3', 'US', 'numeral','8', '4.0', '3.1', '3', 'punctuation', 'particle','to', 'verb','are', 'allow', 'modified', 'secure', 'Mounting', 'used', 'provided', 'wrap', 'using', 'help', 'flip', 'added', 'Recommend', 'adjective','hinged', 'non', 'original', 'better', 'thicker', 'transparent', '-', 'same', 'open', 'standard', 'similar', 'adverb','also', 'more', 'rather', 'well', 'as', 'coordinating conjunction','or', 'and', 'other','i.e.', 'space']

# %%
elements_count = collections.Counter(all_elements)

# %%
elements_count.most_common()
# Out:
# [(',', 17),
#  ('to', 17),
#  ('', 17),
#  ('noun', 15),
#  ('verb', 15),
#  ('space', 15),
#  ('This', 14),
#  ('determiner', 14),
#  ('adjective', 14),
#  ('adposition', 14),
#  ('punctuation', 14),
#  ('coordinating conjunction', 14),
#  ('and', 14),
#  ('pronoun', 13),
#  ('auxiliary', 13),
#  ('is', 13),
#  ('proper noun', 13),
#  ('a', 12),
#  ('adverb', 12),
#  ('.', 12),
#  ('face', 12),
#  ('the', 11),
#  ('-', 11),
#  ('numeral', 11),
#  ('particle', 11),
#  ('shield', 11),
#  ('of', 10),
#  ('for', 10),
#  ('other', 10),
#  ('with', 9),
#  ('on', 9),
#  ('mm', 8),
#  ('as', 8),
#  ('that', 8),
#  ('The', 8),
#  ('can', 8),
#  ('in', 7),
#  ('or', 7),
#  ('be', 7),
#  ('3D', 7),
#  ('material', 6),
#  ('remix', 6),
#  ('using', 6),
#  ('print', 6),
#  ('cut', 6),
#  ('from', 6),
#  ('(', 6),
#  (')', 6),
#  ('subordinating conjunction', 6),
#  ('headband', 6),
#  ('are', 6),
#  ('printed', 6),
#  ('use', 5),
#  ('design', 5),
#  ('standard', 5),
#  ('this', 5),
# ...
